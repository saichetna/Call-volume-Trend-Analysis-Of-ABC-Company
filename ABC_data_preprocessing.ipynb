# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\ADMIN\Downloads\Call_Volume_Trend_Analysis_Project_9.xlsx")
df
# Out:
#            Agent_Name   Agent_ID Customer_Phone_No  Queue_Time(Secs)  \
# 0       Executives 42  1000042.0        98502XXXXX                 2
# 1        Executives 4  1000004.0        80595XXXXX                 0
# 2       Executives 65  1000065.0        70202XXXXX                 0
# 3       Executives 55  1000055.0        96104XXXXX                 1
# 4       Executives 21  1000021.0        82001XXXXX                 0
# ...               ...        ...               ...               ...
# 117983   Executives 7  1000007.0        85399XXXXX                62
# 117984  Executives 36  1000036.0        88397XXXXX                22
# 117985  Executives 48  1000048.0        70035XXXXX                14
# 117986  Executives 33  1000033.0        87773XXXXX                26
# 117987  Executives 58  1000058.0        83800XXXXX                 5
#
#                Date_&_Time  Time Time_Bucket Duration(hh:mm:ss)  \
# 0      2022-01-01 09:02:38     9        9_10           00:01:36
# 1      2022-01-01 09:02:40     9        9_10           00:02:20
# 2      2022-01-01 09:02:49     9        9_10           00:01:25
# 3      2022-01-01 09:02:51     9        9_10           00:01:31
# 4      2022-01-01 09:02:55     9        9_10           00:02:45
# ...                    ...   ...         ...                ...
# 117983 2022-01-23 20:57:58    20       20_21           00:01:32
# 117984 2022-01-23 20:58:24    20       20_21           00:01:14
# 117985 2022-01-23 20:58:34    20       20_21           00:01:48
# 117986 2022-01-23 20:58:53    20       20_21           00:01:13
# 117987 2022-01-23 20:59:12    20       20_21           00:01:22
#
#         Call_Seconds (s) Call_Status  Wrapped _By Ringing IVR _Duration
# 0                     96    answered        Agent     YES      00:00:16
# 1                    140    answered        Agent     YES      00:00:26
# 2                     85    answered  AutoWrapped     YES      00:00:16
# 3                     91    answered        Agent     YES      00:00:25
# 4                    165    answered        Agent     YES      00:00:23
# ...                  ...         ...          ...     ...           ...
# 117983                92    answered        Agent     YES      00:00:42
# 117984                74    answered        Agent     YES      00:00:15
# 117985               108    answered        Agent     YES      00:00:23
# 117986                73    answered        Agent     YES      00:01:05
# 117987                82    answered        Agent     YES      00:00:14
#
# [117988 rows x 13 columns]

# %%
print(df.columns)
# Out:
# Index(['Agent_Name', 'Agent_ID', 'Customer_Phone_No', 'Queue_Time(Secs)',
#        'Date_&_Time', 'Time', 'Time_Bucket', 'Duration(hh:mm:ss)',
#        'Call_Seconds (s)', 'Call_Status', 'Wrapped _By', 'Ringing',
#        'IVR _Duration'],
#       dtype='object')

# %%
null_columns=df.isnull().any()
null_columns
# Out:
# Agent_Name             True
# Agent_ID               True
# Customer_Phone_No     False
# Queue_Time(Secs)      False
# Date_&_Time           False
# Time                  False
# Time_Bucket           False
# Duration(hh:mm:ss)    False
# Call_Seconds (s)      False
# Call_Status           False
# Wrapped _By            True
# Ringing               False
# IVR _Duration         False
# dtype: bool

# %%
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df=df.fillna(df.mode().iloc[0])
df
# Out:
#            Agent_Name   Agent_ID Customer_Phone_No  Queue_Time(Secs)  \
# 0       Executives 42  1000042.0        98502XXXXX                 2
# 1        Executives 4  1000004.0        80595XXXXX                 0
# 2       Executives 65  1000065.0        70202XXXXX                 0
# 3       Executives 55  1000055.0        96104XXXXX                 1
# 4       Executives 21  1000021.0        82001XXXXX                 0
# ...               ...        ...               ...               ...
# 117983   Executives 7  1000007.0        85399XXXXX                62
# 117984  Executives 36  1000036.0        88397XXXXX                22
# 117985  Executives 48  1000048.0        70035XXXXX                14
# 117986  Executives 33  1000033.0        87773XXXXX                26
# 117987  Executives 58  1000058.0        83800XXXXX                 5
#
#                Date_&_Time  Time Time_Bucket Duration(hh:mm:ss)  \
# 0      2022-01-01 09:02:38     9        9_10           00:01:36
# 1      2022-01-01 09:02:40     9        9_10           00:02:20
# 2      2022-01-01 09:02:49     9        9_10           00:01:25
# 3      2022-01-01 09:02:51     9        9_10           00:01:31
# 4      2022-01-01 09:02:55     9        9_10           00:02:45
# ...                    ...   ...         ...                ...
# 117983 2022-01-23 20:57:58    20       20_21           00:01:32
# 117984 2022-01-23 20:58:24    20       20_21           00:01:14
# 117985 2022-01-23 20:58:34    20       20_21           00:01:48
# 117986 2022-01-23 20:58:53    20       20_21           00:01:13
# 117987 2022-01-23 20:59:12    20       20_21           00:01:22
#
#         Call_Seconds (s) Call_Status  Wrapped _By Ringing IVR _Duration
# 0                     96    answered        Agent     YES      00:00:16
# 1                    140    answered        Agent     YES      00:00:26
# 2                     85    answered  AutoWrapped     YES      00:00:16
# 3                     91    answered        Agent     YES      00:00:25
# 4                    165    answered        Agent     YES      00:00:23
# ...                  ...         ...          ...     ...           ...
# 117983                92    answered        Agent     YES      00:00:42
# 117984                74    answered        Agent     YES      00:00:15
# 117985               108    answered        Agent     YES      00:00:23
# 117986                73    answered        Agent     YES      00:01:05
# 117987                82    answered        Agent     YES      00:00:14
#
# [117988 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Agent_Name            0
# Agent_ID              0
# Customer_Phone_No     0
# Queue_Time(Secs)      0
# Date_&_Time           0
# Time                  0
# Time_Bucket           0
# Duration(hh:mm:ss)    0
# Call_Seconds (s)      0
# Call_Status           0
# Wrapped _By           0
# Ringing               0
# IVR _Duration         0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                   Agent_ID  Queue_Time(Secs)      Time  Call_Seconds (s)
# Agent_ID          1.000000          0.325331 -0.143250         -0.362392
# Queue_Time(Secs)  0.325331          1.000000 -0.261452         -0.313767
# Time             -0.143250         -0.261452  1.000000          0.121824
# Call_Seconds (s) -0.362392         -0.313767  0.121824          1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.to_excel('cleaned_ABC_file.xlsx', index=False)

# %%
import os
current_directory = os.getcwd()
file_path = os.path.join(current_directory, 'cleaned_ABC_file.xlsx')
print("File saved at:", file_path)
# Out:
# File saved at: C:\Users\ADMIN\cleaned_ABC_file.xlsx
